# %%
# Importing required libraries
import pandas as pd

# %%
# Reading the csv file 
data = pd.read_csv('titanic_data.csv')

# %%
# Exploring the data
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Funtion to get the type of data
type(data)

# 1. DataFrame 2.Series
# Out:
# pandas.core.frame.DataFrame

# %%
# Extracting a single column from the DataFrame to form a Series
newdata = data['PassengerId']

# %%
type(newdata)
# Out:
# pandas.core.series.Series

# %%
# To remove rows that has NAN values
data.dropna(inplace = True)

# %%
# Conditional slicing
new1 = data['Age'] > 40
new2 = data['PassengerId'] > 500

# %%
# Conditional slicing with mulitple conditions
data_with_conditions = data[(data['Age'] > 40) & (data['PassengerId'] > 500)]

# %%
# View all values in a column
data['Age'].values
# Out:
# array([38.  , 35.  , 54.  ,  4.  , 58.  , 34.  , 28.  , 19.  , 49.  ,
#        65.  , 45.  , 29.  , 25.  , 23.  , 46.  , 71.  , 23.  , 21.  ,
#        47.  , 24.  , 32.5 , 54.  , 19.  , 37.  , 24.  , 36.5 , 22.  ,
#        61.  , 56.  , 50.  ,  1.  ,  3.  , 44.  , 58.  ,  2.  , 40.  ,
#        31.  , 32.  , 38.  , 35.  , 44.  , 37.  , 29.  , 62.  , 30.  ,
#        52.  , 40.  , 58.  , 35.  , 37.  , 63.  , 19.  , 36.  ,  2.  ,
#        50.  ,  0.92, 17.  , 30.  , 24.  , 18.  , 31.  , 40.  , 36.  ,
#        36.  , 16.  , 45.5 , 38.  , 29.  , 41.  , 45.  ,  2.  , 24.  ,
#        24.  , 22.  , 60.  , 24.  , 25.  , 27.  , 36.  , 23.  , 24.  ,
#        33.  , 32.  , 28.  , 50.  , 14.  , 64.  ,  4.  , 52.  , 30.  ,
#        49.  , 65.  , 48.  , 47.  , 23.  , 25.  , 35.  , 58.  , 55.  ,
#        54.  , 25.  , 16.  , 18.  , 36.  , 47.  , 34.  , 30.  , 44.  ,
#        45.  , 22.  , 36.  , 50.  , 17.  , 48.  , 39.  , 53.  , 36.  ,
# ...

# %%
# Get all unique values present in a column
data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Get frequency of each unique element.
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
#Drop a column by name
data.drop(['Name'], axis = 1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Arranging the rows by sorting particular columns with ascending or descending pattern
data.sort_values(by = ['Age','PassengerId'], ascending = [False,False])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 96            97         0       1             Goldschmidt, Mr. George B
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 340          341         1       2        Navratil, Master. Edmond Roger
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 183          184         1       2             Becker, Master. Richard F
# 305          306         1       1        Allison, Master. Hudson Trevor
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
# To create a ew DataFrame from the columns of an older DataFrame

data1 = data[['PassengerId','Survived','Age']]
